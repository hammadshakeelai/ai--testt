# %%
import os

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt 
# from matplotlib import pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# tell shape 
df.shape

# %%
# summary / meta data from data
df.info()

# %%
# missing values
df.isnull() # throws question makes null one true and non null false

# %%
df.isnull().sum() # gives total count of null values in each column

# %%
df.isna().sum() # == df.isnull().sum()

# %%
# fill null values with specified value///// 0 and inplace true means it will change the original data frame
df.fillna(0, inplace=True) # fill null values with 0 and inplace true means it will change the original data frame

# -----------------

# backfill
# bfill
# pad
# ffill
df.fillna(value,axis,downcast,method='ffill', inplace=True, limit=None|5) # fill null values with forward fill method and inplace true means it will change the original data frame

# %%
df.bfill()
df.ffill()

# %%
# bfill // fill null values with backward fill method and inplace true means it will change the original data frame
# ffill // fill null values with forward fill method and inplace true means it will change the original data frame

# %%
# iterative computer # scikit learn library has iterative imputer which is used to fill null values with iterative method and inplace true means it will change the original data frame

# %%
np.nan

# %% [markdown]
# geeks for

# %%
# 10-20 missing data in a column
# if missing data is less than 10% then we can fill it with mean or median or mode
# if missing data is more than 20% then we can drop the column

# %%
df.dropna(how='any') # drop rows with null values
df.dropna(how='all') # drop rows with null values
